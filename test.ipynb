# %%
dictionary={"key":"value","key1":"value2"}

# %%
dictionary["key"]
# Out:
# 'value'

# %%
from box import ConfigBox

# %%
dictionary=ConfigBox({"key":"value","key1":"value2"})

# %%
dictionary.key
# Out:
# 'value'

# %%
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(x=2,y="4")
# Out:
# '44'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(x=2,y="4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_product(x=2,y="4")
#
# File c:\Users\Venks\anaconda3\envs\venv\lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001E042B27AF0> does not match annotation type <class 'int'>

# %% [markdown]
# # Mongo db demo
# - Connection String: " mongodb+srv://amazon_cluster:Amazon_cluster@1@cluster0.iovmgia.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0 "
# - Password: Amazon_cluster@1
# - Username: amazon_cluster
# - mongodb+srv://amazon_cluster:<Amazon_cluster@1>@cluster0.iovmgia.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0

# %% [markdown]
# Can store unstructured data in key: value pairs unlike struuctured relational databases.

# %%
import pandas as pd

# %%
# Load Dataset
df = pd.read_csv(r'C:\Users\Venks\Desktop\Project\MLOPS_Bootcamp\Amazon_Delivery_Time\data\raw\amazon_delivery.csv')

# %%
data=df.to_dict(orient="records")

# %%
len(data)
# Out:
# 43739

# %% [markdown]
# DB_NAME:
# COLLECTION_NAME:
# CONNECTION_URL:

# %%
DB_NAME="Amazon_DB"
COLLECTION_NAME="amazon_data"
CONNECTION_URI="mongodb+srv://amazon_cluster:Amazon_cluster@1@cluster0.iovmgia.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
from pymongo import MongoClient
from urllib.parse import quote_plus

username = quote_plus("amazon_cluster")
password = quote_plus("Amazon_cluster@1")  # your real password

uri = f"mongodb+srv://{username}:{password}@cluster0.iovmgia.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

client = MongoClient(uri)

try:
    client.admin.command('ping')
    print("✅ Pinged your deployment — Successfully connected to MongoDB Atlas!")
except Exception as e:
    print("❌ Connection failed:", e)
# Out:
# ✅ Pinged your deployment — Successfully connected to MongoDB Atlas!

# %%
# --- Insert in batches of 1000 ---
batch_size = 1000
database= client[DB_NAME]
collection=database[COLLECTION_NAME]
for i in range(0, len(data), batch_size):
    batch = data[i:i + batch_size]
    collection.insert_many(batch)
    print(f"Inserted records {i} to {i+len(batch)-1}")

print("✅ All data inserted successfully!")
# Out:
# Inserted records 0 to 999
# Inserted records 1000 to 1999
# Inserted records 2000 to 2999
# Inserted records 3000 to 3999
# Inserted records 4000 to 4999
# Inserted records 5000 to 5999
# Inserted records 6000 to 6999
# Inserted records 7000 to 7999
# Inserted records 8000 to 8999
# Inserted records 9000 to 9999
# Inserted records 10000 to 10999
# Inserted records 11000 to 11999
# Inserted records 12000 to 12999
# Inserted records 13000 to 13999
# Inserted records 14000 to 14999
# Inserted records 15000 to 15999
# Inserted records 16000 to 16999
# Inserted records 17000 to 17999
# Inserted records 18000 to 18999
# Inserted records 19000 to 19999
# Inserted records 20000 to 20999
# Inserted records 21000 to 21999
# Inserted records 22000 to 22999
# Inserted records 23000 to 23999
# Inserted records 24000 to 24999
# Inserted records 25000 to 25999
# Inserted records 26000 to 26999
# Inserted records 27000 to 27999
# Inserted records 28000 to 28999
# Inserted records 29000 to 29999
# ...

# %%
records=collection.find()
records

# %%
database= client[DB_NAME]
collection=database[COLLECTION_NAME]

rec= collection.insert_many(data)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Venks\anaconda3\envs\venv\lib\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Venks\AppData\Local\Temp\ipykernel_11944\772563988.py", line 4, in <module>
#     rec= collection.insert_many(data)
#   File "c:\Users\Venks\anaconda3\envs\venv\lib\site-packages\pymongo\collection.py", line 741, in insert_many
#   File "c:\Users\Venks\anaconda3\envs\venv\lib\site-packages\pymongo\bulk.py", line 432, in execute
#   File "c:\Users\Venks\anaconda3\envs\venv\lib\site-packages\pymongo\bulk.py", line 322, in execute_command
#   File "c:\Users\Venks\anaconda3\envs\venv\lib\site-packages\pymongo\mongo_client.py", line 1076, in _retry_with_session
#   File "c:\Users\Venks\anaconda3\envs\venv\lib\site-packages\pymongo\bulk.py", line 316, in retryable_bulk
# ...

# %%
import dns.resolver
print(dns.resolver.resolve("_mongodb._tcp.cluster0.iovmgia.mongodb.net", "SRV"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 import dns.resolver
# ----> 2 print(dns.resolver.resolve("_mongodb._tcp.cluster0.iovmgia.mongodb.net", "SRV"))
#
# AttributeError: module 'dns.resolver' has no attribute 'resolve'
